# %%
# !add-apt-repository -y ppa:jonathonf/ffmpeg-4
# !apt update
# !apt install -y ffmpeg

# %%
# !pip install datasets>=2.6.1
#!pip install git+https://github.com/huggingface/transformers
# !pip install librosa
# !pip install evaluate>=0.30
# !pip install jiwer
# !pip install gradio
# !pip install -q bitsandbytes datasets accelerate
# !pip install -q git+https://github.com/huggingface/transformers.git@main git+https://github.com/huggingface/peft.git@main

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "0"
model_name_or_path = "openai/whisper-small"
language = "Japanese"
language_abbr = "ja"
task = "transcribe"
dataset_name = "mozilla-foundation/common_voice_16_0"

# %%
from datasets import interleave_datasets, load_dataset

def load_streaming_dataset(dataset_name, dataset_config_name, split, **kwargs):
    if "+" in split:
        # load multiple splits separated by the `+` symbol *with* streaming mode
        dataset_splits = [load_dataset(dataset_name, dataset_config_name, split=split_name, streaming=True, **kwargs) for split_name in split.split("+")]
        # interleave multiple splits to form one dataset
        interleaved_dataset = interleave_datasets(dataset_splits)
        return interleaved_dataset
    else:
        # load a single split *with* streaming mode
        dataset = load_dataset(dataset_name, dataset_config_name, split=split, streaming=True, **kwargs)
        return dataset

# %%
from datasets import IterableDatasetDict

raw_datasets = IterableDatasetDict()

raw_datasets["train"] = load_streaming_dataset(dataset_name, language_abbr, split="train+validation", trust_remote_code=True)  # set split="train+validation" for low-resource
raw_datasets["test"] = load_streaming_dataset(dataset_name, language_abbr, split="test", trust_remote_code=True)

# %%
from transformers import WhisperProcessor
processor = WhisperProcessor.from_pretrained(model_name_or_path, language=language, task=task)

# %%
raw_datasets["train"].features
# Out:
# {'client_id': Value(dtype='string', id=None),
#  'path': Value(dtype='string', id=None),
#  'sentence': Value(dtype='string', id=None),
#  'up_votes': Value(dtype='int64', id=None),
#  'down_votes': Value(dtype='int64', id=None),
#  'age': Value(dtype='string', id=None),
#  'gender': Value(dtype='string', id=None),
#  'accents': Value(dtype='null', id=None),
#  'variant': Value(dtype='null', id=None),
#  'locale': Value(dtype='string', id=None),
#  'segment': Value(dtype='null', id=None)}

# %%
from datasets import Audio
raw_datasets = raw_datasets.cast_column("audio", Audio(sampling_rate=16000))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 from datasets import Audio
# ----> 2 raw_datasets = raw_datasets.cast_column("audio", Audio(sampling_rate=16000))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\dataset_dict.py:2250, in IterableDatasetDict.cast_column(self, column, feature)
#    2222 def cast_column(self, column: str, feature: FeatureType) -> "IterableDatasetDict":
#    2223     """Cast column to feature for decoding.
#    2224     The type casting is applied to all the datasets of the dataset dictionary.
#    2225
#    (...)
#    2247     ```
#    2248     """
#    2249     return IterableDatasetDict(
# -> 2250         {k: dataset.cast_column(column=column, feature=feature) for k, dataset in self.items()}
#    2251     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\dataset_dict.py:2250, in <dictcomp>(.0)
#    2222 def cast_column(self, column: str, feature: FeatureType) -> "IterableDatasetDict":
#    2223     """Cast column to feature for decoding.
#    2224     The type casting is applied to all the datasets of the dataset dictionary.
#    2225
#    (...)
#    2247     ```
#    2248     """
#    2249     return IterableDatasetDict(
# -> 2250         {k: dataset.cast_column(column=column, feature=feature) for k, dataset in self.items()}
#    2251     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\iterable_dataset.py:2130, in IterableDataset.cast_column(self, column, feature)
#    2096 """Cast column to feature for decoding.
#    2097
#    2098 Args:
#    (...)
#    2127 ```
#    2128 """
#    2129 info = self._info.copy()
# -> 2130 info.features[column] = feature
#    2131 # check that it's still valid, especially with regard to task templates
#    2132 try:
#
# TypeError: 'NoneType' object does not support item assignment

# %%
from transformers.models.whisper.english_normalizer import BasicTextNormalizer

do_lower_case = False
do_remove_punctuation = False

normalizer = BasicTextNormalizer()

# %%
def prepare_dataset(batch):
    # load and (possibly) resample audio data to 16kHz
    audio = batch["audio"]

    # compute log-Mel input features from input audio array
    batch["input_features"] = processor.feature_extractor(audio["array"], sampling_rate=audio["sampling_rate"]).input_features[0]
    # compute input length of audio sample in seconds
    batch["input_length"] = len(audio["array"]) / audio["sampling_rate"]

    # optional pre-processing steps
    transcription = batch["sentence"]
    if do_lower_case:
        transcription = transcription.lower()
    if do_remove_punctuation:
        transcription = normalizer(transcription).strip()

    # encode target text to label ids
    batch["labels"] = processor.tokenizer(transcription).input_ids
    return batch

# %%
vectorized_datasets = raw_datasets.map(prepare_dataset, remove_columns=list(next(iter(raw_datasets.values())).features)).with_format("torch")

# %%
vectorized_datasets["train"] = vectorized_datasets["train"].shuffle(
    buffer_size=500,
    seed=0,
)

# %%
max_input_length = 30.0

def is_audio_in_length_range(length):
    return length < max_input_length

# %%
vectorized_datasets["train"] = vectorized_datasets["train"].filter(
    is_audio_in_length_range,
    input_columns=["input_length"],
)

# %%
import torch

from dataclasses import dataclass
from typing import Any, Dict, List, Union


@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lengths and need different padding methods
        # first treat the audio inputs by simply returning torch tensors
        input_features = [{"input_features": feature["input_features"]} for feature in features]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        # get the tokenized label sequences
        label_features = [{"input_ids": feature["labels"]} for feature in features]
        # pad the labels to max length
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        # if bos token is appended in previous tokenization step,
        # cut bos token here as it's append later anyways
        if (labels[:, 0] == self.processor.tokenizer.bos_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)

# %%
# %pip install jiwer
import evaluate
metric = evaluate.load("wer")
# Out:
# Requirement already satisfied: jiwer in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.0.3)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jiwer) (8.1.7)
# Requirement already satisfied: rapidfuzz<4,>=3 in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jiwer) (3.6.1)
# Requirement already satisfied: colorama in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click<9.0.0,>=8.1.3->jiwer) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
def compute_metrics(pred):
    pred_ids = pred.predictions
    label_ids = pred.label_ids

    # replace -100 with the pad_token_id
    label_ids[label_ids == -100] = tokenizer.pad_token_id

    # we do not want to group tokens when computing the metrics
    pred_str = tokenizer.batch_decode(pred_ids, skip_special_tokens=True)
    label_str = tokenizer.batch_decode(label_ids, skip_special_tokens=True)

    wer = 100 * metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %%
# %pip install accelerate
from transformers import WhisperForConditionalGeneration
model = WhisperForConditionalGeneration.from_pretrained(model_name_or_path, load_in_8bit=True, device_map="auto")

# model.hf_device_map - this should be {" ": 0}
# Out:
# Requirement already satisfied: accelerate in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.26.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from accelerate) (5.9.8)
# Requirement already satisfied: pyyaml in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from accelerate) (2.2.0+cu118)
# Requirement already satisfied: huggingface-hub in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from accelerate) (0.4.2)
# Requirement already satisfied: filelock in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.10.0->accelerate) (4.9.0)
# Requirement already satisfied: sympy in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.10.0->accelerate) (2023.10.0)
# Requirement already satisfied: requests in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: colorama in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.42.1->huggingface-hub->accelerate) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->huggingface-hub->accelerate) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\ryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# bin C:\Users\Ryan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\bitsandbytes\libbitsandbytes_cuda118.dll

# %%
model.config.forced_decoder_ids = None
model.config.suppress_tokens = []

# %%
from peft import prepare_model_for_int8_training
model = prepare_model_for_int8_training(model)
# Out:
# C:\Users\Ryan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\peft\utils\other.py:143: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(

# %%
from peft import LoraConfig, PeftModel, LoraModel, LoraConfig, get_peft_model

config = LoraConfig(r=32, lora_alpha=64, target_modules=["q_proj", "v_proj"], lora_dropout=0.05, bias="none")

model = get_peft_model(model, config)
model.print_trainable_parameters()
# Out:
# trainable params: 3,538,944 || all params: 245,273,856 || trainable%: 1.442854145857274

# %%
from transformers import Seq2SeqTrainingArguments

training_args = Seq2SeqTrainingArguments(
    output_dir="C:/Users/Ryan/Desktop/code/whisper/workingfolder/1L",  
    per_device_train_batch_size=2,
    gradient_accumulation_steps=4,  
    learning_rate=1e-3,
    num_train_epochs=5,
    evaluation_strategy="epoch",
    fp16=True,
    per_device_eval_batch_size=1,
    generation_max_length=128,
    logging_steps=15,
    max_steps=500,
    eval_steps=100,
    save_steps=100,
    remove_unused_columns=False, 
    label_names=["labels"], 
    optim="adafactor",
    report_to=["tensorboard"],
)

# %%
from transformers import Seq2SeqTrainer, TrainerCallback, TrainingArguments, TrainerState, TrainerControl
from transformers.trainer_utils import PREFIX_CHECKPOINT_DIR


class SavePeftModelCallback(TrainerCallback):
    def on_save(
        self,
        args: TrainingArguments,
        state: TrainerState,
        control: TrainerControl,
        **kwargs,
    ):
        checkpoint_folder = os.path.join(args.output_dir, f"{PREFIX_CHECKPOINT_DIR}-{state.global_step}")

        peft_model_path = os.path.join(checkpoint_folder, "adapter_model")
        kwargs["model"].save_pretrained(peft_model_path)

        pytorch_model_path = os.path.join(checkpoint_folder, "pytorch_model.bin")
        if os.path.exists(pytorch_model_path):
            os.remove(pytorch_model_path)
        return control


trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=vectorized_datasets["train"],
    eval_dataset=vectorized_datasets["test"],
    data_collator=data_collator,
    # compute_metrics=compute_metrics,
    tokenizer=processor.feature_extractor,
    callbacks=[SavePeftModelCallback],
)
model.config.use_cache = False

# %%
from transformers import Seq2SeqTrainer, TrainerCallback, TrainingArguments, TrainerState, TrainerControl
from transformers.trainer_utils import PREFIX_CHECKPOINT_DIR


class SavePeftModelCallback(TrainerCallback):
    def on_save(
        self,
        args: TrainingArguments,
        state: TrainerState,
        control: TrainerControl,
        **kwargs,
    ):
        checkpoint_folder = os.path.join(args.output_dir, f"{PREFIX_CHECKPOINT_DIR}-{state.global_step}")

        peft_model_path = os.path.join(checkpoint_folder, "adapter_model")
        kwargs["model"].save_pretrained(peft_model_path)

        pytorch_model_path = os.path.join(checkpoint_folder, "pytorch_model.bin")
        if os.path.exists(pytorch_model_path):
            os.remove(pytorch_model_path)
        return control

# %%
trainer.train()
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 trainer.train()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\trainer.py:1645, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1640     self.model_wrapped = self.model
#    1642 inner_training_loop = find_executable_batch_size(
#    1643     self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size
#    1644 )
# -> 1645 return inner_training_loop(
#    1646     args=args,
#    1647     resume_from_checkpoint=resume_from_checkpoint,
#    1648     trial=trial,
#    1649     ignore_keys_for_eval=ignore_keys_for_eval,
#    1650 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\trainer.py:1907, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1904     rng_to_sync = True
#    1906 step = -1
# -> 1907 for step, inputs in enumerate(epoch_iterator):
#    1908     total_batched_samples += 1
#    1909     if rng_to_sync:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\_utils\fetch.py:32, in _IterableDatasetFetcher.fetch(self, possibly_batched_index)
#      30 for _ in possibly_batched_index:
#      31     try:
# ---> 32         data.append(next(self.dataset_iter))
#      33     except StopIteration:
#      34         self.ended = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\iterable_dataset.py:1388, in IterableDataset.__iter__(self)
#    1385         yield formatter.format_row(pa_table)
#    1386     return
# -> 1388 for key, example in ex_iterable:
#    1389     if self.features:
#    1390         # `IterableDataset` automatically fills missing columns with None.
#    1391         # This is done with `_apply_feature_types_on_example`.
#    1392         example = _apply_feature_types_on_example(
#    1393             example, self.features, token_per_repo_id=self._token_per_repo_id
#    1394         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\iterable_dataset.py:867, in FilteredExamplesIterable.__iter__(self)
#     865     yield from ArrowExamplesIterable(self._iter_arrow, {})
#     866 else:
# --> 867     yield from self._iter()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\iterable_dataset.py:904, in FilteredExamplesIterable._iter(self)
#     902             current_idx += 1
#     903 else:
# --> 904     for key, example in iterator:
#     905         # If not batched, we can apply the filtering function direcly
#     906         example = dict(example)
#     907         inputs = format_dict(example) if format_dict else example
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\iterable_dataset.py:987, in BufferShuffledExamplesIterable.__iter__(self)
#     985 # this is the shuffle buffer that we keep in memory
#     986 mem_buffer = []
# --> 987 for x in self.ex_iterable:
#     988     if len(mem_buffer) == buffer_size:  # if the buffer is full, pick and example from it
#     989         i = next(indices_iterator)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\iterable_dataset.py:679, in MappedExamplesIterable.__iter__(self)
#     677     yield from ArrowExamplesIterable(self._iter_arrow, {})
#     678 else:
# --> 679     yield from self._iter()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\iterable_dataset.py:741, in MappedExamplesIterable._iter(self)
#     739             current_idx += 1
#     740 else:
# --> 741     for key, example in iterator:
#     742         # If not batched, we can apply the transform and yield the example directly
#     743         # first copy the example, since we might drop some keys
#     744         example = dict(example)
#     745         example = format_dict(example) if format_dict else example
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\iterable_dataset.py:1122, in TypedExamplesIterable.__iter__(self)
#    1116 def __iter__(self):
#    1117     # Then for each example, `TypedExamplesIterable` automatically fills missing columns with None.
#    1118     # This is done with `_apply_feature_types_on_example`.
#    1119     for key, example in self.ex_iterable:
#    1120         yield (
#    1121             key,
# -> 1122             _apply_feature_types_on_example(example, self.features, token_per_repo_id=self.token_per_repo_id),
#    1123         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\iterable_dataset.py:1082, in _apply_feature_types_on_example(example, features, token_per_repo_id)
#    1080 encoded_example = features.encode_example(example)
#    1081 # Decode example for Audio feature, e.g.
# -> 1082 decoded_example = features.decode_example(encoded_example, token_per_repo_id=token_per_repo_id)
#    1083 return decoded_example
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\features\features.py:1939, in Features.decode_example(self, example, token_per_repo_id)
#    1925 def decode_example(self, example: dict, token_per_repo_id: Optional[Dict[str, Union[str, bool, None]]] = None):
#    1926     """Decode example with custom feature decoding.
#    1927
#    1928     Args:
#    (...)
#    1936         `dict[str, Any]`
#    1937     """
# -> 1939     return {
#    1940         column_name: decode_nested_example(feature, value, token_per_repo_id=token_per_repo_id)
#    1941         if self._column_requires_decoding[column_name]
#    1942         else value
#    1943         for column_name, (feature, value) in zip_dict(
#    1944             {key: value for key, value in self.items() if key in example}, example
#    1945         )
#    1946     }
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\features\features.py:1940, in <dictcomp>(.0)
#    1925 def decode_example(self, example: dict, token_per_repo_id: Optional[Dict[str, Union[str, bool, None]]] = None):
#    1926     """Decode example with custom feature decoding.
#    1927
#    1928     Args:
#    (...)
#    1936         `dict[str, Any]`
#    1937     """
#    1939     return {
# -> 1940         column_name: decode_nested_example(feature, value, token_per_repo_id=token_per_repo_id)
#    1941         if self._column_requires_decoding[column_name]
#    1942         else value
#    1943         for column_name, (feature, value) in zip_dict(
#    1944             {key: value for key, value in self.items() if key in example}, example
#    1945         )
#    1946     }
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\features\features.py:1340, in decode_nested_example(schema, obj, token_per_repo_id)
#    1337 elif isinstance(schema, (Audio, Image)):
#    1338     # we pass the token to read and decode files from private repositories in streaming mode
#    1339     if obj is not None and schema.decode:
# -> 1340         return schema.decode_example(obj, token_per_repo_id=token_per_repo_id)
#    1341 return obj
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\features\audio.py:183, in Audio.decode_example(self, value, token_per_repo_id)
#     180         token = None
#     182     download_config = DownloadConfig(token=token)
# --> 183     with xopen(path, "rb", download_config=download_config) as f:
#     184         array, sampling_rate = sf.read(f)
#     186 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\download\streaming_download_manager.py:507, in xopen(file, mode, download_config, *args, **kwargs)
#     504 if is_local_path(main_hop):
#     505     # ignore fsspec-specific kwargs
#     506     kwargs.pop("block_size", None)
# --> 507     return open(main_hop, mode, *args, **kwargs)
#     508 # add headers and cookies for authentication on the HF Hub and for Google Drive
#     509 file, storage_options = _prepare_path_and_storage_options(file_str, download_config=download_config)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Ryan\\.cache\\huggingface\\datasets\\downloads\\extracted\\bd5bded09f47c47abe27bca4e48a9b9e675519e21004445e559998148d9e7626\\ja_train_0\\common_voice_ja_22739650.mp3'

# %%
#trainer.push_to_hub("sin2piusc/whisper-largev2-FT-CV16-JP")

# %%
peft_model_id = "whisper-medium-1L"
#model.push_to_hub(peft_model_id)
print(peft_model_id)
# Out:
# whisper-medium-1L

# %%
from peft import PeftModel, PeftConfig
from transformers import WhisperForConditionalGeneration, Seq2SeqTrainer

peft_model_id = "C:/Users/Ryan/Desktop/code/whisper/workingfolder1L/whisper-medium-1L"
peft_config = PeftConfig.from_pretrained(peft_model_id)
model = WhisperForConditionalGeneration.from_pretrained(peft_config.base_model_name_or_path, load_in_8bit=True, device_map="auto")
model = PeftModel.from_pretrained(model, peft_model_id)

# %%
from torch.utils.data import DataLoader
from tqdm import tqdm
import numpy as np
import gc

eval_dataloader = DataLoader(vectorized_datasets["test"], batch_size=8, collate_fn=data_collator)
forced_decoder_ids = processor.get_decoder_prompt_ids(language=language, task=task)

model.eval()
for step, batch in enumerate(tqdm(eval_dataloader)):
    with torch.cuda.amp.autocast():
        with torch.no_grad():
            generated_tokens = (
                model.generate(
                    input_features=batch["input_features"].to("cuda"),
                    forced_decoder_ids=forced_decoder_ids,
                    max_new_tokens=255,
                )
                .cpu()
                .numpy()
            )
            labels = batch["labels"].cpu().numpy()
            labels = np.where(labels != -100, labels, processor.tokenizer.pad_token_id)
            decoded_preds = processor.tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)
            decoded_labels = processor.tokenizer.batch_decode(labels, skip_special_tokens=True)
            metric.add_batch(
                predictions=decoded_preds,
                references=decoded_labels,
            )
    del generated_tokens, labels, batch
    gc.collect()
wer = 100 * metric.compute()
print(f"{wer=}")

# %%
from torch.utils.data import DataLoader
from tqdm import tqdm
import numpy as np
import gc
from transformers.models.whisper.english_normalizer import BasicTextNormalizer
normalizer = BasicTextNormalizer()
forced_decoder_ids = processor.get_decoder_prompt_ids(language=language, task=task)

model.eval()
for step, batch in enumerate(tqdm(eval_dataloader)):
    with torch.cuda.amp.autocast():
        with torch.no_grad():
            generated_tokens= model.generate(input_features=batch["input_features"].to("cuda"),
                                             forced_decoder_ids=forced_decoder_ids,
                                             max_new_tokens=255).cpu().numpy()
            labels = batch["labels"].cpu().numpy()
            labels = np.where(labels != -100, labels, processor.tokenizer.pad_token_id)
            decoded_preds = processor.tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)
            decoded_labels = processor.tokenizer.batch_decode(labels, skip_special_tokens=True)
            metric.add_batch(
                predictions=[normalizer(pred).strip() for pred in decoded_preds],
                references=[normalizer(label).strip() for label in decoded_labels],
            )
    # if step==0:
    #     break
    del generated_tokens, labels, batch
    gc.collect()
normalized_wer = 100 * metric.compute()
print(f"{normalized_wer=}")

# %%
for pred,label in zip(decoded_preds,decoded_labels):
  print(f"{pred=}, {label=}")

# %%
import torch
import gradio as gr
from transformers import (
    AutomaticSpeechRecognitionPipeline,
    WhisperForConditionalGeneration,
    WhisperTokenizer,
    WhisperProcessor,
)
from peft import PeftModel, PeftConfig


peft_model_id = "whisper-medium-1L"
language = "Japanese"
task = "transcribe"
peft_config = PeftConfig.from_pretrained(peft_model_id)
model = WhisperForConditionalGeneration.from_pretrained(
    peft_config.base_model_name_or_path, load_in_8bit=True, device_map="auto"
)

model = PeftModel.from_pretrained(model, peft_model_id)
tokenizer = WhisperTokenizer.from_pretrained(peft_config.base_model_name_or_path, language=language, task=task)
processor = WhisperProcessor.from_pretrained(peft_config.base_model_name_or_path, language=language, task=task)
feature_extractor = processor.feature_extractor
forced_decoder_ids = processor.get_decoder_prompt_ids(language=language, task=task)
pipe = AutomaticSpeechRecognitionPipeline(model=model, tokenizer=tokenizer, feature_extractor=feature_extractor)


def transcribe(audio):
    with torch.cuda.amp.autocast():
        text = pipe(audio, generate_kwargs={"forced_decoder_ids": forced_decoder_ids}, max_new_tokens=255)["text"]
    return text


iface = gr.Interface(
    fn=transcribe,
    inputs=gr.Audio(source="microphone", type="filepath"),
    outputs="text",
    title="PEFT LoRA + INT8 Whisper Large V2 Japanese",
    description="Japanese speech recognition using `PEFT-LoRA+INT8` fine-tuned Whisper Large V2 model (cv16).",
)

iface.launch(share=True)
